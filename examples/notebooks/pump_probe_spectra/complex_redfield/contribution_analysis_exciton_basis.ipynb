# %% [markdown]
# # Import needed packages

# %%
import numpy as np
from scipy.sparse.linalg import expm_multiply
import matplotlib.pyplot as plt
from seaborn import set_context
set_context('talk')

from redfield_package.spectral_density import SpectralDensity
from redfield_package.pump_probe import PumpProbeSpectraCalculator
from redfield_package.tensors import RedfieldTensorComplex
from redfield_package.tensors_double import RedfieldTensorComplexDouble
from redfield_package.utils import overdamped_brownian,underdamped_brownian,get_timeaxis,wn2ips

# %% [markdown]
# # Define the system

# %% [markdown]
# **Hamiltonian (1/cm)**

# %%
nchrom = 3 #numero di cromofori

E0 = 10000
energy_gap = 100
coupling_12 = 100
coupling_23 = 30
coupling_13 = 10
H = np.zeros((nchrom,nchrom)) #hamiltonian

H[0] = np.asarray([E0          , coupling_12     , coupling_13     ])
H[1] = np.asarray([coupling_12 , E0+energy_gap   , coupling_23     ])
H[2] = np.asarray([coupling_13 , coupling_23     , E0+2*energy_gap ])

# %%
H
# Out:
# array([[1.00e+04, 1.00e+02, 1.00e+01],
#        [1.00e+02, 1.01e+04, 3.00e+01],
#        [1.00e+01, 3.00e+01, 1.02e+04]])

# %% [markdown]
# **Transition dipoles (Debye)**

# %%
dipoles = np.ones([nchrom,3])

# %% [markdown]
# **Temperature (Kelvin)**

# %%
temp = 298

# %% [markdown]
# **Spectral density**

# %%
freq_axis_SD = np.arange(0.1,4000,0.1)

# %%
SD_data = overdamped_brownian(freq_axis_SD,30,37)
SD_data = SD_data + underdamped_brownian(freq_axis_SD,5,50,1000)

# %%
plt.plot(freq_axis_SD,SD_data,color='black');
plt.xlim(0,2000);
plt.ylim(0,22000)
plt.title('SPECTRAL DENSITY ($cm^{-1}$)');
plt.xlabel('FREQUENCY ($cm^{-1}$)');
plt.minorticks_on()

# %%
SD_obj = SpectralDensity(freq_axis_SD,SD_data,temperature=temp)

# %% [markdown]
# **Time axis (cm)**

# %%
energies = np.diag(H)
time_axis = get_timeaxis(SD_obj.Reorg,energies,5)
SD_obj.time = time_axis

# %% [markdown]
# **Relaxation Tensors**

# %%
rel_tens_obj = RedfieldTensorComplex(H,SD_obj)
rel_tens_obj_double = RedfieldTensorComplexDouble(H,SD_obj)

# %% [markdown]
# # Excited State Dynamics

# %% [markdown]
# **Load from file**

# %%
data = np.loadtxt('../excited_state_dynamics/excited_state_dynamics.dat')
time_axis_ps = data[:,0]
rho_t_site_ = data[:,1:]
rho_t_site = rho_t_site_.reshape((time_axis_ps.size,nchrom,nchrom))

# %% [markdown]
# **Convert to exciton basis**

# %%
rho_t_exc = rel_tens_obj.transform(rho_t_site)

# %% [markdown]
# **Extract the population**

# %%
pop_t_exc = np.einsum('tkk->tk',rho_t_exc)

# %% [markdown]
# # Spectra calculation

# %%
spectrum_obj = PumpProbeSpectraCalculator(rel_tens_obj,rel_tens_obj_double,include_dephasing=True)

# %%
spectrum_obj.calc_components_lineshape(dipoles=dipoles)
freq_axis,GSB_a,SE_a,ESA_a,PP_a = spectrum_obj.get_pump_probe_a(pop_t_exc)
freq_axis,GSB,SE,ESA,PP = spectrum_obj.get_pump_probe(pop_t_exc)

# %% [markdown]
# # Check the results

# %% [markdown]
# **Time after time**

# %%
for time_idx,time in enumerate(time_axis_ps):

    fig, axs = plt.subplots(2,2,gridspec_kw={'wspace': 0.5, 'hspace': 0.4})
    fig.set_size_inches(11,9)
    fig.suptitle('Delay time: ' + str(time) + ' ps')

    axs[0,0].plot([],[],label = 'Exciton',color= 'white')
    axs[0,1].plot([],[],label = 'Exciton',color= 'white')
    axs[1,0].plot([],[],label = 'Exciton',color= 'white')
    axs[1,1].plot([],[],label = 'Exciton',color= 'white')
    
    axs[0,0].plot(freq_axis,GSB,label = 'Total',color='black',ls='--')
    axs[0,1].plot(freq_axis,SE[time_idx],label = 'Total',color='black',ls='--')
    axs[1,0].plot(freq_axis,ESA[time_idx],label = 'Total',color='black',ls='--')
    axs[1,1].plot(freq_axis,PP[time_idx],label = 'Total',color='black',ls='--')
    
    for exciton in range(nchrom):
        
        #GSB
        axs[0,0].plot(freq_axis,GSB_a[exciton],label = str(exciton+1))
        axs[0,0].set_title('GSB')

        #SE
        axs[0,1].plot(freq_axis,SE_a[exciton,time_idx],label = str(exciton+1))
        axs[0,1].set_title('SE')

        #ESA
        axs[1,0].plot(freq_axis,ESA_a[exciton,time_idx],label = str(exciton+1))
        axs[1,0].set_title('ESA')

        #FULL
        axs[1,1].set_title('PUMP-PROBE')
        axs[1,1].plot(freq_axis,PP_a[exciton,time_idx],label = str(exciton+1))

    for ax1 in axs:
        for ax2 in ax1:
            ax2.set_xlim(9000,12000)
            ax2.minorticks_on()
            ax2.set_xlabel("Wavelenght (nm)")
            ax2.set_ylabel("Intensity")
            ax2.legend()

# %% [markdown]
# **Exciton after exciton**

# %%
for exciton in range(nchrom):

    fig, axs = plt.subplots(2,2,gridspec_kw={'wspace': 0.5, 'hspace': 0.4})
    fig.set_size_inches(11,9)
    fig.suptitle('Exciton ' + str(exciton+1))
    
    #GSB
    axs[0,0].plot(freq_axis,GSB_a[exciton],label = time_string)
    axs[0,0].set_title('GSB')
    
    for time_idx,time in enumerate(time_axis_ps):
        
        time_string = str(time)+'ps'
        

        #SE
        axs[0,1].plot(freq_axis,SE_a[exciton,time_idx],label = time_string)
        axs[0,1].set_title('SE')

        #ESA
        axs[1,0].plot(freq_axis,ESA_a[exciton,time_idx],label = time_string)
        axs[1,0].set_title('ESA')

        #FULL
        axs[1,1].set_title('PUMP-PROBE')
        axs[1,1].plot(freq_axis,PP_a[exciton,time_idx],label = time_string)

    for ax1 in axs:
        for ax2 in ax1:
            ax2.set_xlim(9000,12000)
            ax2.minorticks_on()
            ax2.set_xlabel("Wavelenght (nm)")
            ax2.set_ylabel("Intensity")
            if not ax2 == axs[0,0]:
                ax2.legend()
